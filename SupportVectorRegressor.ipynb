# %% [markdown]
# <a href="https://colab.research.google.com/github/GOLISHYAMP/Colab_Notebooks/blob/main/SupportVectorRegressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = sns.load_dataset('tips')

# %%
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # **So, here my dependent variable will be the total_bill and rest will be the independent variables.**
# I have to make the categorical data into the numeric form.\
# For that i have to do the label encoder and one hot encoder

# %%
dataset['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
dataset['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
dataset['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
dataset['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
# So, I can use the label encoder on sex, smoker and time\
# and one hot encoder on day

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dataset['sex'] = le.fit_transform(dataset['sex'])
dataset['smoker'] = le.fit_transform(dataset['smoker'])
dataset['time'] = le.fit_transform(dataset['time'])

# %%
dataset
# Out:
#      total_bill   tip  sex  smoker   day  time  size
# 0         16.99  1.01    0       0   Sun     0     2
# 1         10.34  1.66    1       0   Sun     0     3
# 2         21.01  3.50    1       0   Sun     0     3
# 3         23.68  3.31    1       0   Sun     0     2
# 4         24.59  3.61    0       0   Sun     0     4
# ..          ...   ...  ...     ...   ...   ...   ...
# 239       29.03  5.92    1       0   Sat     0     3
# 240       27.18  2.00    0       1   Sat     0     2
# 241       22.67  2.00    1       1   Sat     0     2
# 242       17.82  1.75    1       0   Sat     0     2
# 243       18.78  3.00    0       0  Thur     0     2
#
# [244 rows x 7 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('hot_encoder', OneHotEncoder(drop='first'), [4])], remainder='passthrough')

# %%
dataset = ct.fit_transform(dataset)

# %%
dataset[:5, :]
# Out:
# array([[ 0.  ,  1.  ,  0.  , 16.99,  1.01,  0.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  , 10.34,  1.66,  1.  ,  0.  ,  0.  ,  3.  ],
#        [ 0.  ,  1.  ,  0.  , 21.01,  3.5 ,  1.  ,  0.  ,  0.  ,  3.  ],
#        [ 0.  ,  1.  ,  0.  , 23.68,  3.31,  1.  ,  0.  ,  0.  ,  2.  ],
#        [ 0.  ,  1.  ,  0.  , 24.59,  3.61,  0.  ,  0.  ,  0.  ,  4.  ]])

# %%
df = pd.DataFrame(dataset)

# %%
df.head()
# Out:
#      0    1    2      3     4    5    6    7    8
# 0  0.0  1.0  0.0  16.99  1.01  0.0  0.0  0.0  2.0
# 1  0.0  1.0  0.0  10.34  1.66  1.0  0.0  0.0  3.0
# 2  0.0  1.0  0.0  21.01  3.50  1.0  0.0  0.0  3.0
# 3  0.0  1.0  0.0  23.68  3.31  1.0  0.0  0.0  2.0
# 4  0.0  1.0  0.0  24.59  3.61  0.0  0.0  0.0  4.0

# %%
X = df[[0,1,2,4,5,6,7,8]]

# %%
X
# Out:
#        0    1    2     4    5    6    7    8
# 0    0.0  1.0  0.0  1.01  0.0  0.0  0.0  2.0
# 1    0.0  1.0  0.0  1.66  1.0  0.0  0.0  3.0
# 2    0.0  1.0  0.0  3.50  1.0  0.0  0.0  3.0
# 3    0.0  1.0  0.0  3.31  1.0  0.0  0.0  2.0
# 4    0.0  1.0  0.0  3.61  0.0  0.0  0.0  4.0
# ..   ...  ...  ...   ...  ...  ...  ...  ...
# 239  1.0  0.0  0.0  5.92  1.0  0.0  0.0  3.0
# 240  1.0  0.0  0.0  2.00  0.0  1.0  0.0  2.0
# 241  1.0  0.0  0.0  2.00  1.0  1.0  0.0  2.0
# 242  1.0  0.0  0.0  1.75  1.0  0.0  0.0  2.0
# 243  0.0  0.0  1.0  3.00  0.0  0.0  0.0  2.0
#
# [244 rows x 8 columns]

# %%
y = df.iloc[:, 3]

# %%
print(type(y))
y
# Out:
# <class 'pandas.core.series.Series'>
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: 3, Length: 244, dtype: float64

# %% [markdown]
# # **Train test split of the dataset**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state = 31)

# %% [markdown]
# # **Model training**

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train, y_train)
y_pred = svr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 32.428751643355
# 0.4481504191881336

# %% [markdown]
# # **Very less accuracy, lets do hyperparameter tunning using gridsearchCV**

# %%
params = {
    'kernel' : ['linear', 'rbf', 'poly', 'sigmoid'],
    'C' : [100, 10, 1, 0.1, 0.01, 0.001],
    'gamma' : [1, 0.1, 0.01, 0.001],
    'degree' : [2, 3]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(estimator=SVR(), param_grid=params, scoring='r2',n_jobs=-1, refit = True, cv = 5)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [100, 10, 1, 0.1, 0.01, 0.001], 'degree': [2, 3],
#                          'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='r2')

# %%
y_pred = grid.predict(X_test)

# %%
grid.best_params_
# Out:
# {'C': 10, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}

# %%
grid.best_score_
# Out:
# 0.5354256099592865

# %%
from sklearn.metrics import r2_score, mean_squared_error
print(r2_score(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.30024722217844846
# 41.120098361475314
